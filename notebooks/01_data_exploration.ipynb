# %%
import pandas as pd

#load only first 1000 rows 
df = pd.read_csv('../data/raw/flights_sample_3m.csv', nrows =1000)

print(f"Loaded {len(df)} rows")
print(f"Number of columns: {len(df.columns)}")
# Out:
# Loaded 1000 rows
# Number of columns: 32

# %%
#show all 32 columns
print(df.columns.tolist())
# Out:
# ['FL_DATE', 'AIRLINE', 'AIRLINE_DOT', 'AIRLINE_CODE', 'DOT_CODE', 'FL_NUMBER', 'ORIGIN', 'ORIGIN_CITY', 'DEST', 'DEST_CITY', 'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY', 'TAXI_OUT', 'WHEELS_OFF', 'WHEELS_ON', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY', 'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE', 'DELAY_DUE_CARRIER', 'DELAY_DUE_WEATHER', 'DELAY_DUE_NAS', 'DELAY_DUE_SECURITY', 'DELAY_DUE_LATE_AIRCRAFT']

# %%
#show first 5 rows so we see how data looks
df.head()
# Out:
#       FL_DATE                AIRLINE                AIRLINE_DOT AIRLINE_CODE  \
# 0  2019-01-09  United Air Lines Inc.  United Air Lines Inc.: UA           UA
# 1  2022-11-19   Delta Air Lines Inc.   Delta Air Lines Inc.: DL           DL
# 2  2022-07-22  United Air Lines Inc.  United Air Lines Inc.: UA           UA
# 3  2023-03-06   Delta Air Lines Inc.   Delta Air Lines Inc.: DL           DL
# 4  2020-02-23       Spirit Air Lines       Spirit Air Lines: NK           NK
#
#    DOT_CODE  FL_NUMBER ORIGIN          ORIGIN_CITY DEST  \
# 0     19977       1562    FLL  Fort Lauderdale, FL  EWR
# 1     19790       1149    MSP      Minneapolis, MN  SEA
# 2     19977        459    DEN           Denver, CO  MSP
# 3     19790       2295    MSP      Minneapolis, MN  SFO
# 4     20416        407    MCO          Orlando, FL  DFW
#
#                DEST_CITY  ...  DIVERTED  CRS_ELAPSED_TIME  ELAPSED_TIME  \
# 0             Newark, NJ  ...       0.0             186.0         176.0
# ...

# %%
# delay related columns 
df[['FL_DATE', 'AIRLINE_CODE', 'ORIGIN', 'DEST', 'DEP_DELAY', 'ARR_DELAY', 'CANCELLED']].head(10)
# Out:
#       FL_DATE AIRLINE_CODE ORIGIN DEST  DEP_DELAY  ARR_DELAY  CANCELLED
# 0  2019-01-09           UA    FLL  EWR       -4.0      -14.0        0.0
# 1  2022-11-19           DL    MSP  SEA       -6.0       -5.0        0.0
# 2  2022-07-22           UA    DEN  MSP        6.0        0.0        0.0
# 3  2023-03-06           DL    MSP  SFO       -1.0       24.0        0.0
# 4  2020-02-23           NK    MCO  DFW       -2.0       -1.0        0.0
# 5  2019-07-31           WN    DAL  OKC      147.0      141.0        0.0
# 6  2023-06-11           AA    DCA  BOS       -9.0      -29.0        0.0
# 7  2019-07-08           YX    HSV  DCA       -6.0       23.0        0.0
# 8  2023-02-12           NK    IAH  LAX       -3.0      -11.0        0.0
# 9  2020-08-22           AS    SEA  FAI       -9.0        1.0        0.0

# %%
# Statistical summary of the delay columns
df[['DEP_DELAY', 'ARR_DELAY', 'DISTANCE', 'AIR_TIME']].describe()
# Out:
#          DEP_DELAY    ARR_DELAY     DISTANCE    AIR_TIME
# count   972.000000   972.000000  1000.000000  972.000000
# mean      9.727366     3.887860   815.163000  113.592593
# std      49.922749    53.956354   591.392336   70.347956
# min     -21.000000   -51.000000    68.000000   15.000000
# 25%      -5.000000   -15.000000   372.750000   61.000000
# 50%      -3.000000    -7.000000   651.000000   96.000000
# 75%       7.250000     7.000000  1052.750000  144.000000
# max    1069.000000  1124.000000  3972.000000  480.000000

# %%
# How many cancelled flights vs how many missing DEP_DELAY values?
print("Cancelled flights in sample:", df['CANCELLED'].sum())
print("Missing DEP_DELAY values:", df['DEP_DELAY'].isna().sum())
print("Missing ARR_DELAY values:", df['ARR_DELAY'].isna().sum())
# Out:
# Cancelled flights in sample: 28.0
# Missing DEP_DELAY values: 28
# Missing ARR_DELAY values: 28

# %%
# ============================================
# PHASE 3 — DATA EXPLORATION FINDINGS
# Date: Monday June 22, 2026
# ============================================
# 
# Dataset: BTS flights_sample_3m.csv (3M row sample)
# Year coverage: 2019-2023
# Columns: 32
#
# KEY FINDINGS:
# 1. Mean DEP_DELAY = 9.7 min, but median = -3 min
#    → Distribution is right-skewed. Most flights are on-time;
#    delays come from a long tail of badly-delayed outliers.
#
# 2. Mean ARR_DELAY = 3.9 min (vs DEP_DELAY 9.7)
#    → Pilots recover ~6 min of delay in the air on average.
#
# 3. Missing data: exactly 28 rows missing DEP_DELAY,
#    and exactly 28 cancelled flights. Confirmed they
#    are the same rows. No other missing data sources.
#
# 4. Distance range 68 - 3972 miles → US domestic only.
#
# NEXT STEPS (Tuesday afternoon):
# - Load full dataset into SQLite database
# - Write SQL queries to answer specific questions
# - Generate descriptive stats by airline, route, day of week
# ============================================
